# %%
from duckduckgo_search import DDGS
from fastcore.all import *

# %%
ddgs = DDGS()

# %%
def search_images(term, max_images=30):
    print(f"Searching for '{term}'")
    return L(ddgs.images(term, max_results=max_images)).itemgot('image')

# %%
urls = search_images(term='bird photos', max_images=1)
urls[0]
# Out:
# Searching for 'bird photos'
# 'https://images.pexels.com/photos/326900/pexels-photo-326900.jpeg?cs=srgb&dl=wood-flight-bird-326900.jpg&fm=jpg'

# %%
from fastdownload import download_url
dest = 'bird.jpg'
download_url(urls[0], dest, show_progress=True)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='180224' class='' max='173489' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       103.88% [180224/173489 00:00<00:00]
#     </div>
# Path('bird.jpg')

# %%
from fastai.vision.all import *
im = Image.open(dest)
im.to_thumb(256, 256)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from fastai.vision.all import *
#       2 im = Image.open(dest)
#       3 im.to_thumb(256, 256)
#
# File ~/anaconda3/envs/fastai_book/lib/python3.10/site-packages/fastai/vision/all.py:1
# ----> 1 from . import models
#       2 from ..basics import *
#       3 from ..callback.all import *
#
# File ~/anaconda3/envs/fastai_book/lib/python3.10/site-packages/fastai/vision/models/__init__.py:1
# ----> 1 from . import xresnet
#       2 from . import unet
#       3 from .tvm import *
#
# File ~/anaconda3/envs/fastai_book/lib/python3.10/site-packages/fastai/vision/models/xresnet.py:7
#       3 # AUTOGENERATED! DO NOT EDIT! File to edit: ../../../nbs/11_vision.models.xresnet.ipynb.
#       4
#       5 # %% ../../../nbs/11_vision.models.xresnet.ipynb 2
#       6 from __future__ import annotations
# ----> 7 from ...torch_basics import *
#       8 try: from torchvision.models.utils import load_state_dict_from_url
#       9 except ModuleNotFoundError: from torch.hub import load_state_dict_from_url
#
# File ~/anaconda3/envs/fastai_book/lib/python3.10/site-packages/fastai/torch_basics.py:9
#       6     # workaround "OMP: Error #15: Initializing libiomp5.dylib, but found libomp.dylib already initialized"
#       7     os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'
# ----> 9 from .imports import *
#      10 from .torch_imports import *
#      11 from .torch_core import *
#
# File ~/anaconda3/envs/fastai_book/lib/python3.10/site-packages/fastai/imports.py:29
#      27 from pandas.api.types import CategoricalDtype,is_numeric_dtype
#      28 from numpy import array,ndarray
# ---> 29 from scipy import ndimage
#      30 from pdb import set_trace
#      31 from fastcore.all import *
#
# File <frozen importlib._bootstrap>:1075, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File ~/anaconda3/envs/fastai_book/lib/python3.10/site-packages/scipy/__init__.py:134, in __getattr__(name)
#     132 def __getattr__(name):
#     133     if name in submodules:
# --> 134         return _importlib.import_module(f'scipy.{name}')
#     135     else:
#     136         try:
#
# File ~/anaconda3/envs/fastai_book/lib/python3.10/importlib/__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~/anaconda3/envs/fastai_book/lib/python3.10/site-packages/scipy/ndimage/__init__.py:155
#     153 from ._fourier import *
#     154 from ._interpolation import *
# --> 155 from ._measurements import *
#     156 from ._morphology import *
#     158 # Deprecated namespaces, to be removed in v2.0.0
#
# File ~/anaconda3/envs/fastai_book/lib/python3.10/site-packages/scipy/ndimage/_measurements.py:36
#      34 from . import _ni_label
#      35 from . import _nd_image
# ---> 36 from . import _morphology
#      38 __all__ = ['label', 'find_objects', 'labeled_comprehension', 'sum', 'mean',
#      39            'variance', 'standard_deviation', 'minimum', 'maximum', 'median',
#      40            'minimum_position', 'maximum_position', 'extrema', 'center_of_mass',
#      41            'histogram', 'watershed_ift', 'sum_labels', 'value_indices']
#      44 def label(input, structure=None, output=None):
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1006, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:688, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:879, in exec_module(self, module)
#
# File <frozen importlib._bootstrap_external>:1012, in get_code(self, fullname)
#
# File <frozen importlib._bootstrap_external>:672, in _compile_bytecode(data, name, bytecode_path, source_path)
#
# KeyboardInterrupt:

# %%
download_url(search_images('forest photos', max_images=1)[0], 'forest.jpg', show_progress=False)
Image.open('forest.jpg').to_thumb(256,256)
# Out:
# Searching for 'forest photos'
# <PIL.Image.Image image mode=RGB size=256x160>

# %%
searches = 'forest', 'bird'
path = Path('bird_or_not')
from time import sleep

# %%
for o in searches:
    dest = (path/o)
    dest.mkdir(exist_ok=True, parents=True)
    download_images(dest, urls=search_images(f'{o} photo'))
    sleep(10)
    download_images(dest, urls=search_images(f'{o} sun photo'))
    sleep(10)
    download_images(dest, urls=search_images(f'{o} shade photo'))
    sleep(10)
    resize_images(path/o, max_size=400, dest=path/o)
# Out:
# Searching for 'forest photo'
# Searching for 'forest sun photo'
# Searching for 'forest shade photo'
# Searching for 'bird photo'
# Searching for 'bird sun photo'
# Searching for 'bird shade photo'

# %%
failed = verify_images(get_image_files(path))
failed.map(Path.unlink)
len(failed)
# Out:
# 4

# %%
dls = DataBlock(
    blocks=(ImageBlock, CategoryBlock),
    get_items=get_image_files,
    splitter=RandomSplitter(valid_pct=0.2, seed=42),
    get_y=parent_label,
    item_tfms=[Resize(192, method='squish')]
).dataloaders(path, bs=32)

dls.show_batch
# Out:
# <bound method TfmdDL.show_batch of <fastai.data.core.TfmdDL object at 0x7fdd68c6b6d0>>

# %%
learn = vision_learner(dls, resnet18, metrics=error_rate)
learn.fine_tune(3)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /home/bach/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:27<00:00, 1.70MB/s]
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.940154</td>
#       <td>1.588908</td>
#       <td>0.419355</td>
#       <td>00:09</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.317921</td>
#       <td>0.403766</td>
#       <td>0.096774</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.234386</td>
#       <td>0.108693</td>
#       <td>0.096774</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.161614</td>
#       <td>0.112930</td>
#       <td>0.064516</td>
#       <td>00:03</td>
#     </tr>
#   </tbody>
# </table>
# /home/bach/anaconda3/envs/fastai_book/lib/python3.10/site-packages/torch/autograd/graph.py:744: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at /opt/conda/envs/bld/conda-bld/pytorch-select_1719512383855/work/aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass

# %%
is_bird, _, probs =learn.predict(PILImage.create('bird.jpg'))
print(f"This is a: {is_bird}.")
print(f"Probability it's a bird: {probs[0]:.4f}")
# Out:
# This is a: bird.
# Probability it's a bird: 0.9998
